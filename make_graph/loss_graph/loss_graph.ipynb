# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import arviz as az

# %%
dataset = "Yelp2"

au_loss_ls = np.load(f"./all_loss_{dataset}_DirectAU.npy")
au_loss_ls = au_loss_ls[3:]

uctrl_loss_ls = np.load(f"./all_loss_{dataset}_UCTRL.npy")
uctrl_loss_ls = uctrl_loss_ls[3:]

# %%
len(uctrl_loss_ls)
# Out:
# 109

# %%
# if pop_mode:
plt.scatter(uctrl_loss_ls[:,0], uctrl_loss_ls[:,1], color ='blue') #all
# plt.scatter(uctrl_loss_ls[:,2], uctrl_loss_ls[:,3], color ='blue') #user pop
# plt.scatter(uctrl_loss_ls[:,4], uctrl_loss_ls[:,5], color ='blue') #user unpop
# plt.scatter(uctrl_loss_ls[:,6], uctrl_loss_ls[:,7], color='blue') #item pop
# plt.scatter(uctrl_loss_ls[:,8], uctrl_loss_ls[:,9], color='blue') #item unpop

# else:
plt.scatter(au_loss_ls[:,0], au_loss_ls[:,1], color ='red') #all
# plt.scatter(au_loss_ls[:,2], au_loss_ls[:,3], color ='red') #user pop
# plt.scatter(au_loss_ls[:,4], au_loss_ls[:,5], color ='red') #user unpop
# plt.scatter(au_loss_ls[:,6], au_loss_ls[:,7], color='red') #item pop
# plt.scatter(au_loss_ls[:,8], au_loss_ls[:,9], color='red') #item unpop
